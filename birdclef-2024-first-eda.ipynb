# %% [markdown]
# # BirdCLEF 2024 Initial Notebook
# * Classify audio recordings of birds
# * First look at frequency based features
#     * FFT analysis
#     * Librosa stuff, harmonic, percussive, zero-crossings, etc.
#     * Run first model on these features, using gradient boosted trees (Catboost, XGBoost, LightGBM)
# * Then save spectrograms as image files and set up to treat it as an image classification problem

# %% [markdown]
# # Imports

# %%
import os
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns
sns.set_style('whitegrid')

import soundfile as sf
import librosa
import librosa.display
import IPython.display as ipd

from tqdm.auto import tqdm


import warnings
warnings.filterwarnings("ignore")

# !pip install -q scienceplots
import scienceplots
plt.style.use(['science','no-latex'])

# %% [markdown]
# # Load Data

# %%
root_dir = '/kaggle/input/birdclef-2024'
train_audio_dir = '/kaggle/input/birdclef-2024/train_audio/'
train = pd.read_csv(root_dir + '/train_metadata.csv') 
tax = pd.read_csv(root_dir + '/eBird_Taxonomy_v2021.csv') 
ss = pd.read_csv(root_dir + '/sample_submission.csv')

# %% [markdown]
# # Top Level View

# %%
# print all sets - assuming train,test, ss
print(f'Training Data Shape: {train.shape}') 
display(train.head()) 
print(f'Tax Data Shape: {tax.shape}') 
display(tax.head()) 
print(f'Sample Submission Shape: {ss.shape}') 
display(ss.head())
# Out:
# Training Data Shape: (24459, 12)
#   primary_label secondary_labels      type  latitude  longitude  \
# 0        asbfly               []  ['call']   39.2297   118.1987
# 1        asbfly               []  ['song']   51.4030   104.6401
# 2        asbfly               []  ['song']   36.3319   127.3555
# 3        asbfly               []  ['call']   21.1697    70.6005
# 4        asbfly               []  ['call']   15.5442    73.7733
#
#       scientific_name             common_name  \
# 0  Muscicapa dauurica  Asian Brown Flycatcher
# 1  Muscicapa dauurica  Asian Brown Flycatcher
# 2  Muscicapa dauurica  Asian Brown Flycatcher
# 3  Muscicapa dauurica  Asian Brown Flycatcher
# 4  Muscicapa dauurica  Asian Brown Flycatcher
#
#                               author  \
# 0                     Matt Slaymaker
# 1                   Magnus Hellström
# 2                      Stuart Fisher
# 3                          vir joshi
# 4  Albert Lastukhin & Sergei Karpeev
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     5.0
# 1  Creative Commons Attribution-NonCommercial-Sha...     2.5
# 2  Creative Commons Attribution-NonCommercial-Sha...     2.5
# 3  Creative Commons Attribution-NonCommercial-Sha...     4.0
# 4  Creative Commons Attribution-NonCommercial-Sha...     4.0
#
#                                  url             filename
# 0  https://www.xeno-canto.org/134896  asbfly/XC134896.ogg
# 1  https://www.xeno-canto.org/164848  asbfly/XC164848.ogg
# 2  https://www.xeno-canto.org/175797  asbfly/XC175797.ogg
# 3  https://www.xeno-canto.org/207738  asbfly/XC207738.ogg
# 4  https://www.xeno-canto.org/209218  asbfly/XC209218.ogg
# Tax Data Shape: (16753, 9)
#    TAXON_ORDER CATEGORY SPECIES_CODE       PRIMARY_COM_NAME  \
# 0            1  species      ostric2         Common Ostrich
# 1            6  species      ostric3         Somali Ostrich
# 2            7    slash       y00934  Common/Somali Ostrich
# 3            8  species      grerhe1           Greater Rhea
# 4           14  species      lesrhe2            Lesser Rhea
#
#                          SCI_NAME            ORDER1  \
# 0                Struthio camelus  Struthioniformes
# 1          Struthio molybdophanes  Struthioniformes
# 2  Struthio camelus/molybdophanes  Struthioniformes
# 3                  Rhea americana        Rheiformes
# 4                    Rhea pennata        Rheiformes
#
#                       FAMILY SPECIES_GROUP REPORT_AS
# 0  Struthionidae (Ostriches)     Ostriches       NaN
# 1  Struthionidae (Ostriches)           NaN       NaN
# 2  Struthionidae (Ostriches)           NaN       NaN
# 3            Rheidae (Rheas)         Rheas       NaN
# 4            Rheidae (Rheas)           NaN       NaN
# Sample Submission Shape: (3, 183)
#                   row_id    asbfly   ashdro1   ashpri1   ashwoo2   asikoe2  \
# 0   soundscape_1446779_5  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  soundscape_1446779_10  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  soundscape_1446779_15  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     asiope1   aspfly1   aspswi1   barfly1    barswa    bcnher   bkcbul1  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     bkrfla1   bkskit1    bkwsti   bladro1   blaeag1   blakit1   blhori1  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     blnmon1   blrwar1   bncwoo3   brakit1   brasta1  ...   sqtbul1   stbkin1  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  ...  0.005495  0.005495
#
#     sttwoo1   thbwar1   tibfly3   tilwar1   vefnut1   vehpar1   wbbfly1  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     wemhar1   whbbul2   whbsho3   whbtre1   whbwag1   whbwat1   whbwoo2  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     whcbar1   whiter2    whrmun   whtkin2    woosan   wynlau1   yebbab1  \
# 0  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 1  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
# 2  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495  0.005495
#
#     yebbul3   zitcis1
# 0  0.005495  0.005495
# 1  0.005495  0.005495
# 2  0.005495  0.005495
#
# [3 rows x 183 columns]

# %%
# looks like there are 182 bird types
print(f'Length of unique bird types: {len(train.common_name.unique())}\n')
print(f'Bird types: {list(train.common_name.unique())}')
# Out:
# Length of unique bird types: 182
#
# Bird types: ['Asian Brown Flycatcher', 'Ashy Drongo', 'Ashy Prinia', 'Ashy Woodswallow', 'Asian Koel', 'Asian Openbill', 'Indian Paradise-Flycatcher', 'Asian Palm-Swift', 'Black-and-orange Flycatcher', 'Barn Swallow', 'Black-crowned Night-Heron', 'Flame-throated Bulbul', 'Black-rumped Flameback', 'Black-winged Kite', 'Black-winged Stilt', 'Black Drongo', 'Black Eagle', 'Black Kite', 'Black-hooded Oriole', 'Black-naped Monarch', "Blyth's Reed Warbler", 'Brown-capped Pygmy Woodpecker', 'Brahminy Kite', 'Brahminy Starling', 'Brown-cheeked Fulvetta', 'Brown Fish-Owl', 'Brown Boobook', 'Brown Shrike', 'Bronzed Drongo', 'Bronze-winged Jacana', 'Brown Wood-Owl', 'Blue-tailed Bee-eater', 'Bar-winged Flycatcher-shrike', 'Cattle Egret', 'Chestnut-headed Bee-eater', 'Common Hawk-Cuckoo', 'Common Flameback', 'Common Greenshank', 'Common Iora', 'Common Kingfisher', 'Eurasian Moorhen', 'Common Myna', 'Indian Peafowl', 'Common Rosefinch', 'Common Sandpiper', 'Common Tailorbird', 'Coppersmith Barbet', 'Crimson-backed Sunbird', 'Crested Goshawk', 'Malabar Barbet', 'Crested Serpent-Eagle', 'Dark-fronted Babbler', 'Oriental Darter', 'Western Yellow Wagtail', 'Asian Emerald Dove', 'Eurasian Collared-Dove', 'Indian Blackbird', 'Eurasian Coot', 'Forest Wagtail', 'Garganey', 'Glossy Ibis', 'Golden-fronted Leafbird', 'Gray Heron', 'Green Bee-eater', 'Greater Coucal', 'Great Egret', 'Greater Flameback', 'Great Hornbill', 'Gray Junglefowl', 'Great Eared-Nightjar', 'Greenish Warbler', 'Green Sandpiper', 'Green Warbler', 'Greater Racket-tailed Drongo', 'Gray Francolin', 'Jungle Nightjar', 'Gray Wagtail', 'Gray-breasted Prinia', 'Gray-headed Canary-Flycatcher', 'Heart-spotted Woodpecker', 'Eurasian Hoopoe', 'House Crow', 'House Sparrow', 'Indian Blue Robin', 'Indian Pitta', 'Indian Robin', 'Indian Roller', 'Indian Yellow Tit', 'Indian Golden Oriole', 'Indian Pond-Heron', 'Indian Scimitar-Babbler', 'Indian Scops-Owl', 'Intermediate Egret', 'Indian Spot-billed Duck', "Jerdon's Bushlark", 'Jungle Babbler', 'Jungle Myna', 'Jungle Owlet', 'Kentish Plover', 'Palani Laughingthrush', 'Large-billed Crow', 'Laughing Dove', 'Large-billed Leaf Warbler', 'Lesser Yellownape', 'Lesser Whistling-Duck', 'Little Ringed Plover', 'Little Egret', 'Little Grebe', 'Little Spiderhunter', 'Little Swift', "Loten's Sunbird", 'Malabar Gray Hornbill', 'Malabar Parakeet', 'Malabar Trogon', 'Malabar Woodshrike', 'Marsh Sandpiper', 'Malabar Whistling-Thrush', 'Mountain Imperial-Pigeon', 'Nilgiri Flycatcher', 'Nilgiri Wood-Pigeon', 'Scaly-breasted Munia', 'Oriental Honey-buzzard', 'Paddyfield Pipit', 'Pale-billed Flowerpecker', 'Painted Stork', 'Pied Bushchat', 'Pied Kingfisher', 'Gray-bellied Cuckoo', 'Nilgiri Flowerpecker', 'Plain Prinia', 'Plum-headed Parakeet', 'Gray-fronted Green-Pigeon', 'Purple Heron', 'Purple-rumped Sunbird', 'Purple Sunbird', 'Gray-headed Swamphen', 'Puff-throated Babbler', 'Red Spurfowl', 'Red-rumped Swallow', 'Red-vented Bulbul', 'Red-whiskered Bulbul', 'Red-wattled Lapwing', 'Rock Pigeon', 'Rose-ringed Parakeet', 'Rosy Starling', 'Rufous Babbler', 'Rufous Treepie', 'Rufous Woodpecker', 'Rusty-tailed Flycatcher', 'Spot-bellied Eagle-Owl', 'Orange Minivet', 'Shikra', 'Small Minivet', 'Southern Hill Myna', 'Speckled Piculet', 'Spotted Dove', 'Spotted Owlet', 'Square-tailed Bulbul', 'Stork-billed Kingfisher', 'Streak-throated Woodpecker', 'Thick-billed Warbler', "Tickell's Blue Flycatcher", "Tickell's Leaf Warbler", 'Velvet-fronted Nuthatch', 'Vernal Hanging-Parrot', 'White-bellied Blue Flycatcher', 'Eurasian Marsh-Harrier', 'White-browed Bulbul', 'White-bellied Sholakili', 'White-bellied Treepie', 'White-browed Wagtail', 'White-breasted Waterhen', 'White-bellied Woodpecker', 'White-cheeked Barbet', 'Whiskered Tern', 'White-rumped Munia', 'White-throated Kingfisher', 'Wood Sandpiper', 'Wayanad Laughingthrush', 'Yellow-billed Babbler', 'Yellow-browed Bulbul', 'Zitting Cisticola']

# %% [markdown]
# # Missing Data

# %%
def df_info(df): 
  summary = pd.DataFrame(df.dtypes, columns=['dtypes']) 
  summary['missing#'] = df.isna().sum() 
  summary['missing%'] = (df.isna().sum())/len(df) 
  summary['uniques'] = df.nunique().values 
  summary['count'] = df.count().values 
  return summary

df_info(train).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f5502_row0_col1, #T_f5502_row0_col2, #T_f5502_row1_col1, #T_f5502_row1_col2, #T_f5502_row2_col1, #T_f5502_row2_col2, #T_f5502_row3_col4, #T_f5502_row4_col4, #T_f5502_row5_col1, #T_f5502_row5_col2, #T_f5502_row6_col1, #T_f5502_row6_col2, #T_f5502_row7_col1, #T_f5502_row7_col2, #T_f5502_row8_col1, #T_f5502_row8_col2, #T_f5502_row8_col3, #T_f5502_row9_col1, #T_f5502_row9_col2, #T_f5502_row9_col3, #T_f5502_row10_col1, #T_f5502_row10_col2, #T_f5502_row11_col1, #T_f5502_row11_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f5502_row0_col3, #T_f5502_row5_col3, #T_f5502_row6_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f5502_row0_col4, #T_f5502_row1_col4, #T_f5502_row2_col4, #T_f5502_row3_col1, #T_f5502_row3_col2, #T_f5502_row4_col1, #T_f5502_row4_col2, #T_f5502_row5_col4, #T_f5502_row6_col4, #T_f5502_row7_col4, #T_f5502_row8_col4, #T_f5502_row9_col4, #T_f5502_row10_col3, #T_f5502_row10_col4, #T_f5502_row11_col3, #T_f5502_row11_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f5502_row1_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f5502_row2_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_f5502_row3_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_f5502_row4_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_f5502_row7_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_f5502">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5502_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_f5502_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_f5502_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_f5502_level0_col3" class="col_heading level0 col3" >uniques</th>
#       <th id="T_f5502_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5502_level0_row0" class="row_heading level0 row0" >primary_label</th>
#       <td id="T_f5502_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_f5502_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f5502_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f5502_row0_col3" class="data row0 col3" >182</td>
#       <td id="T_f5502_row0_col4" class="data row0 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row1" class="row_heading level0 row1" >secondary_labels</th>
#       <td id="T_f5502_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_f5502_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f5502_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_f5502_row1_col3" class="data row1 col3" >491</td>
#       <td id="T_f5502_row1_col4" class="data row1 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row2" class="row_heading level0 row2" >type</th>
#       <td id="T_f5502_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_f5502_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_f5502_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_f5502_row2_col3" class="data row2 col3" >918</td>
#       <td id="T_f5502_row2_col4" class="data row2 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row3" class="row_heading level0 row3" >latitude</th>
#       <td id="T_f5502_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_f5502_row3_col1" class="data row3 col1" >378</td>
#       <td id="T_f5502_row3_col2" class="data row3 col2" >0.015454</td>
#       <td id="T_f5502_row3_col3" class="data row3 col3" >9098</td>
#       <td id="T_f5502_row3_col4" class="data row3 col4" >24081</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row4" class="row_heading level0 row4" >longitude</th>
#       <td id="T_f5502_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_f5502_row4_col1" class="data row4 col1" >378</td>
#       <td id="T_f5502_row4_col2" class="data row4 col2" >0.015454</td>
#       <td id="T_f5502_row4_col3" class="data row4 col3" >9182</td>
#       <td id="T_f5502_row4_col4" class="data row4 col4" >24081</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row5" class="row_heading level0 row5" >scientific_name</th>
#       <td id="T_f5502_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_f5502_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_f5502_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_f5502_row5_col3" class="data row5 col3" >182</td>
#       <td id="T_f5502_row5_col4" class="data row5 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row6" class="row_heading level0 row6" >common_name</th>
#       <td id="T_f5502_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_f5502_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f5502_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_f5502_row6_col3" class="data row6 col3" >182</td>
#       <td id="T_f5502_row6_col4" class="data row6 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row7" class="row_heading level0 row7" >author</th>
#       <td id="T_f5502_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_f5502_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_f5502_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_f5502_row7_col3" class="data row7 col3" >1942</td>
#       <td id="T_f5502_row7_col4" class="data row7 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row8" class="row_heading level0 row8" >license</th>
#       <td id="T_f5502_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_f5502_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_f5502_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_f5502_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_f5502_row8_col4" class="data row8 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row9" class="row_heading level0 row9" >rating</th>
#       <td id="T_f5502_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_f5502_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_f5502_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_f5502_row9_col3" class="data row9 col3" >11</td>
#       <td id="T_f5502_row9_col4" class="data row9 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row10" class="row_heading level0 row10" >url</th>
#       <td id="T_f5502_row10_col0" class="data row10 col0" >object</td>
#       <td id="T_f5502_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_f5502_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_f5502_row10_col3" class="data row10 col3" >24458</td>
#       <td id="T_f5502_row10_col4" class="data row10 col4" >24459</td>
#     </tr>
#     <tr>
#       <th id="T_f5502_level0_row11" class="row_heading level0 row11" >filename</th>
#       <td id="T_f5502_row11_col0" class="data row11 col0" >object</td>
#       <td id="T_f5502_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_f5502_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_f5502_row11_col3" class="data row11 col3" >24459</td>
#       <td id="T_f5502_row11_col4" class="data row11 col4" >24459</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * All data is there except for some (1.5%) lat/lon coordinates

# %% [markdown]
# ## Secondary Labels

# %%
# look at secondary labels
secondary = train.secondary_labels.value_counts()
vals = secondary.values
plt.plot(vals[1:])
plt.title('Secondary Labels - Value Counts')
plt.show()

# %%
np.sum(vals[vals==1])  # 343 values with 1
# Out:
# 343

# %% [markdown]
# ### Takeaways
# * there are 182 birds to classify
# * From sumbission file, looks like it is broken into 5 sec chunks and need to predict a probability for each bird in each time interval.
# * of 24459 records, 22567 have no secondary labels, means that only 1892 have other birds, or around 8%
#     * Maybe start with records that have no secondary labels.

# %% [markdown]
# ## Check for any missing .ogg files

# %%
files = train.filename.values

# %%
exist_count = 0
for file in tqdm(files):
        if os.path.exists(train_audio_dir + file):
            exist_count +=1
        else:
            print(f'file: {file} not found.')
print(f'exist count = {exist_count}')
print(f'All files accounted for: {exist_count == len(train)}')
# Out:
#   0%|          | 0/24459 [00:00<?, ?it/s]
# exist count = 24459
# All files accounted for: True

# %% [markdown]
# ## Look at a sample audio file plot

# %%
file_idx = 0

data, samplerate = sf.read(train_audio_dir + files[file_idx])

# final time stamp is the length over the sample rate
end = len(data)/samplerate
print(f'end time: {end}')

time = np.linspace(0,end, len(data))

plt.figure(figsize=(10,3))
plt.plot(time,data)
plt.title(f'File: {file}, sample rate: {samplerate/1000} kHz, Duration: {end:.2f}')
plt.xlabel('Time (sec)')
plt.ylabel('Amplitude')
plt.show()
# samplerate = 32khz
# Out:
# end time: 27.35021875

# %% [markdown]
# ## Use Librosa instead
# * plots look better, more functionality

# %%
# look at waveform properties
file_idx = 0
fname = train_audio_dir + files[file_idx]

wf, sr = librosa.load(fname)
print(f'Waveform shape: {wf.shape}\nSample Rate: {sr}')
# Out:
# Waveform shape: (603073,)
# Sample Rate: 22050

# %% [markdown]
# * Why is librosa telling me this is a 22.05 kHz sample rate, where as using soundfile library shows 32kHz ???
#     * Need to investigate this...

# %%
# zoom in a level or two
fig, ax = plt.subplots(nrows=4, sharex=False,figsize=(15,16))
librosa.display.waveshow(wf, sr=sr, ax=ax[0],alpha=0.5)
ax[0].set(title='Raw Audio Sample All')
ax[0].label_outer()
librosa.display.waveshow(wf[50000:150000], sr=sr, ax=ax[1],alpha=0.5)
ax[1].set(title='Raw Audio Sample 100000 Points')
ax[1].label_outer()
librosa.display.waveshow(wf[50000:60000], sr=sr, ax=ax[2],alpha=0.5)
ax[2].set(title='Raw Audio Sample 10000 Points')
ax[2].label_outer()
librosa.display.waveshow(wf[50000:50500], sr=sr, ax=ax[3],alpha=0.5)
ax[3].set(title='Raw Audio Sample 500 Points')
ax[3].label_outer()

# %% [markdown]
# ## More Librosa Feature Extraction
#
# * Beat tempo
# * Harmonic and Percussive Components
# * RMS
# * Zero crossings

# %% [markdown]
# ### Tempo

# %%
# tempo
tempo, _ = librosa.beat.beat_track(y=wf, sr=sr)
print(f'The tempo in beats/min = {tempo:.2f}')
# Out:
# The tempo in beats/min = 92.29

# %% [markdown]
# ### Harmonic and Percussive components

# %%
# plot
fig, ax = plt.subplots(nrows=3, sharex=True,figsize=(14,10))
librosa.display.waveshow(wf[135000:165000], sr=sr, ax=ax[0], label='Original')
ax[0].set(title='Original Waveform')
ax[0].label_outer()

wf_harm, wf_perc = librosa.effects.hpss(wf)
librosa.display.waveshow(wf_harm[135000:165000], sr=sr, alpha=0.5, ax=ax[1], label='Harmonic')
ax[1].set(title='Harmonic')
#ax[1].legend()
librosa.display.waveshow(wf_perc[135000:165000], sr=sr, color='r', alpha=0.5, ax=ax[2], label='Percussive')
ax[2].set(title='Percussive');

# %% [markdown]
# ## Listen to a sample

# %%
fname = train_audio_dir + files[file_idx]
print(f'filename: {fname}')
ipd.Audio(fname)
# Out:
# filename: /kaggle/input/birdclef-2024/train_audio/asbfly/XC134896.ogg
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Spectrogram
# * For method 2: Save specrogram waveforms as images, train like an image classifier.
# * Check out the first file.

# %%
ft = librosa.stft(wf)
ft_db = librosa.amplitude_to_db(np.abs(ft), ref=np.max)
ft_db.shape
# Out:
# (1025, 1178)

# %%
fig,ax = plt.subplots(figsize=(10,5))
img = librosa.display.specshow(ft_db,x_axis='time', y_axis='log',ax=ax)
ax.set_title(f'Spectogram: {fname}')
fig.colorbar(img, ax=ax);

# %% [markdown]
# ## Mel Spectrogram

# %%
ms = librosa.feature.melspectrogram(y=wf, sr=sr,n_mels=256,)
ms_db = librosa.amplitude_to_db(ms,ref=np.max)

# plot
fig,ax = plt.subplots(figsize=(10,5))
img = librosa.display.specshow(ms_db,x_axis='time', y_axis='log',ax=ax)
ax.set_title(f'Mel Spectogram: {fname}');

# %% [markdown]
# ### Takeaways
# * Mel is dark for this file
# * Need to evaluate as to if spectrogram or mel spectrogram will give better results

# %% [markdown]
# ## Harmonic and Percussive Spectrograms

# %%
# spectograms - regular first - it is done a slightly different way than the MEL
ft_harm = librosa.stft(wf_harm)
ft_harm_db = librosa.amplitude_to_db(np.abs(ft_harm), ref=np.max)
ft_perc = librosa.stft(wf_perc)
ft_perc_db = librosa.amplitude_to_db(np.abs(ft_perc), ref=np.max)

# MEL spectograms
ms_harm = librosa.feature.melspectrogram(y=wf_harm, sr=sr,n_mels=256,)
ms_harm_db = librosa.amplitude_to_db(ms_harm,ref=np.max)
ms_perc = librosa.feature.melspectrogram(y=wf_perc, sr=sr,n_mels=256,)
ms_perc_db = librosa.amplitude_to_db(ms_perc,ref=np.max)

fig, ax = plt.subplots(nrows=4,sharex=True, figsize=(14,16))
#librosa.display.waveshow(wf, sr=sr, ax=ax[0], label='Original')
#librosa.display.specshow(wf_harm,x_axis='time', y_axis='log',ax=ax)
librosa.display.specshow(ms_harm_db,x_axis='time', y_axis='log',ax=ax[0])
ax[0].set_title('Harmonic Melspectogram')
librosa.display.specshow(ms_harm_db,x_axis='time', y_axis='log',ax=ax[1])
ax[1].set_title('Percussive Melspectogram')
librosa.display.specshow(ft_harm_db,x_axis='time', y_axis='log',ax=ax[2])
ax[2].set_title('Harmonic Spectogram')
librosa.display.specshow(ft_perc_db,x_axis='time', y_axis='log',ax=ax[3])
ax[3].set_title('Percussive Spectogram')
# Out:
# Text(0.5, 1.0, 'Percussive Spectogram')

# %% [markdown]
# ## Zero crossings

# %%
FRAME_SIZE = 1024
HOP_LENGTH = 512

# Zero crossings for both harmonic and percussive
wf_zcr = librosa.feature.zero_crossing_rate(wf,frame_length=FRAME_SIZE,hop_length=HOP_LENGTH)[0] * FRAME_SIZE
wf_harm_zcr = librosa.feature.zero_crossing_rate(wf_harm,frame_length=FRAME_SIZE,hop_length=HOP_LENGTH)[0] * FRAME_SIZE

wf_perc_zcr = librosa.feature.zero_crossing_rate(wf_perc,frame_length=FRAME_SIZE,hop_length=HOP_LENGTH)[0] * FRAME_SIZE

# %%
fig,ax = plt.subplots(nrows=3,sharex=True,figsize=(14,8))

librosa.display.waveshow(wf_zcr, sr=sr, alpha=0.8, ax=ax[0], label='Original Waveform')
ax[0].set(title='Original Waveform Zero Crossings')
librosa.display.waveshow(wf_harm_zcr, sr=sr, alpha=0.8, ax=ax[1], label='Harmonic Waveform')
ax[1].set(title='Harmonic Waveform Zero Crossings')
librosa.display.waveshow(wf_perc_zcr, sr=sr, alpha=0.8, ax=ax[2], label='Percussive Waveform')
ax[2].set(title='Percussive Waveform Zero Crossings')
# Out:
# [Text(0.5, 1.0, 'Percussive Waveform Zero Crossings')]

# %% [markdown]
# ## Models
# * TBD, after EDA
# * gradient boosted models for frequency based features
# * fastai/pytorch/keras for spectrogram classification

# %% [markdown]
# # Submission
# * Need to do the stupid verification thing first

# %%
ss.to_csv('submission.csv',index=False)
